# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('dataset (1).csv')
df
# Out:
#        VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0      JTMEB3FV6N     Monroe       Key West    FL        33040        2022
# 1      1G1RD6E45D      Clark       Laughlin    NV        89029        2013
# 2      JN1AZ0CP8B     Yakima         Yakima    WA        98901        2011
# 3      1G1FW6S08H     Skagit       Concrete    WA        98237        2017
# 4      3FA6P0SU1K  Snohomish        Everett    WA        98201        2019
# ...           ...        ...            ...   ...          ...         ...
# 13277  JTMFB3FV6M       King  Mercer Island    WA        98040        2021
# 13278  WBY8P2C00M  Snohomish   Lake Stevens    WA        98258        2021
# 13279  3C3CFFGE0D       King        Seattle    WA        98112        2013
# 13280  5YJSA1E21H       King     Clyde Hill    WA        98004        2017
# 13281  1G1FX6S01J       King       Kirkland    WA        98034        2018
#
# ...

# %%
df.shape
# Out:
# (13282, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13282 entries, 0 to 13281
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         13282 non-null  object
#  1   County                                             13282 non-null  object
#  2   City                                               13282 non-null  object
#  3   State                                              13282 non-null  object
#  4   Postal Code                                        13282 non-null  int64
#  5   Model Year                                         13282 non-null  int64
#  6   Make                                               13282 non-null  object
#  7   Model                                              13282 non-null  object
# ...

# %%
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     BOLT EV          Battery Electric Vehicle (BEV)
# 4      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              42
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                0
# City                                                  0
# State                                                 0
# Postal Code                                           0
# Model Year                                            0
# Make                                                  0
# Model                                                 0
# Electric Vehicle Type                                 0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     0
# Electric Range                                        0
# Base MSRP                                             0
# Legislative District                                 36
# DOL Vehicle ID                                        0
# Vehicle Location                                      2
# Electric Utility                                     57
# 2020 Census Tract                                     0
# ...

# %%
df.shape
# Out:
# (13282, 17)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (13224, 17)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
# Univariate Analysis of Numerical Columns
plt.figure(figsize=(10, 6))
sns.histplot(df['Electric Range'], bins=20, kde=True)
plt.title('Distribution of Electric Range')
plt.show()

# %%
df['Log Base MSRP'] = np.log1p(df['Base MSRP'])
plt.figure(figsize=(10, 6))
sns.histplot(df['Log Base MSRP'], bins=10, kde=True)
plt.title('Log-Transformed Distribution of Base MSRP')
plt.show()

# %%
print("Unique Makes  :", df['Make'].nunique())
print("Unique Models :", df['Model'].nunique())
top_makes = df['Make'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_makes.index, y=top_makes.values,palette='viridis')
plt.title('Top 10 Vehicle Makes')
plt.xticks(rotation=45)
plt.show()
# Out:
# Unique Makes  : 32
# Unique Models : 101
# <ipython-input-45-34e6d5d162f7>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
top_10_counties = df["County"].value_counts().sort_values(ascending=False).head(10)
print("*"*5, "Top 10 Counties", "*"*5)
for county, count in top_10_counties.items():
  print("{0} : {1}".format(county, count))
# Out:
# ***** Top 10 Counties *****
# King : 6984
# Snohomish : 1503
# Pierce : 954
# Clark : 777
# Thurston : 596
# Kitsap : 470
# Whatcom : 316
# Spokane : 295
# Benton : 156
# Skagit : 147

# %%
top_10_counties_sorted = top_10_counties.sort_values(ascending=True)
plt.figure(figsize=(10, 6))
ax = sns.barplot(y=top_10_counties_sorted.index, x=top_10_counties_sorted.values, palette='rocket_r')
plt.title('Top 10 Vehicle Makes')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-48-1e9a151f3989>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **Univariate analysis**

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
EV=px.scatter(df, x = 'Model Year', y = 'Electric Range', title='Model Year VS Electric Range')
EV.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Scatter_model = px.scatter(df, x = 'Model Year', y = 'Base MSRP', title='Model Year VS Base MSRP')
Scatter_model.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Ev_range_model = px.box(df, x= 'Electric Vehicle Type', y='Electric Range', title='Electric Vehicle Type vs Electric Range')
Ev_range_model.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ev_box_model = px.violin(df, x= 'Electric Vehicle Type', y='Electric Range', title='Electric Vehicle Type vs Electric Range')
ev_box_model.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
box_ev = px.box(df, x= 'Clean Alternative Fuel Vehicle (CAFV) Eligibility', y = 'Electric Range',
                title = 'Clean Alternative Fuel Vehicle (CAFV) Eligibility VS Electric Range')
box_ev.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
mean_Electric_Range = df.groupby('Model Year')['Electric Range'].mean().reset_index()
fig_line = px.line(mean_Electric_Range, x= 'Model Year', y='Electric Range', title='Model_Year VS mean_Electric_Range',
                   labels=({'Model Year': 'Model Year', 'Electric Range': 'mean_Electric_Range'}))
fig_line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_counts = df.groupby(['Model Year', 'Electric Vehicle Type']).size().reset_index(name='County')
fig_bar = px.bar(df_counts, x = 'Model Year', y= 'County' ,color='Electric Vehicle Type', title='Model Year Vs Electric Vehicle Type')
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df, names='Model Year', values='Base MSRP', title='Base MSRP by Model Year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                            int64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
Ev_count_pincode = df.groupby(['Postal Code', 'Model Year', 'State']).size().reset_index(name='Number_of_EV_vehicles')

# %%
Ev_count_pincode
# Out:
#       Postal Code  Model Year State  Number_of_EV_vehicles
# 0           98001        2012    WA                      1
# 1           98001        2013    WA                      3
# 2           98001        2014    WA                      1
# 3           98001        2015    WA                      1
# 4           98001        2016    WA                      3
# ...           ...         ...   ...                    ...
# 2709        99403        2015    WA                      1
# 2710        99403        2017    WA                      1
# 2711        99403        2019    WA                      1
# 2712        99403        2020    WA                      2
# 2713        99403        2021    WA                      2
#
# [2714 rows x 4 columns]

# %%
State_date = Ev_count_pincode[Ev_count_pincode['State'] =='WA']

# %%
State_date
# Out:
#       Postal Code  Model Year State  Number_of_EV_vehicles
# 0           98001        2012    WA                      1
# 1           98001        2013    WA                      3
# 2           98001        2014    WA                      1
# 3           98001        2015    WA                      1
# 4           98001        2016    WA                      3
# ...           ...         ...   ...                    ...
# 2709        99403        2015    WA                      1
# 2710        99403        2017    WA                      1
# 2711        99403        2019    WA                      1
# 2712        99403        2020    WA                      2
# 2713        99403        2021    WA                      2
#
# [2714 rows x 4 columns]

# %%
state_data = df.groupby('State')['VIN (1-10)'].count().reset_index()
state_data.columns = ['State', 'EV Count']
fig = px.choropleth(
    state_data,
    locations='State',
    locationmode='USA-states',
    color='EV Count',
    color_continuous_scale='Purples',
    scope='usa',
    labels={'EV Count': 'Number of EV Vehicles'},
    title='Number of Electric Vehicles by State'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
count_by_state = df.groupby("State").size().reset_index(name="count")
fig_1 = px.choropleth(
    count_by_state,
    locations="State",
    color="count",
    locationmode="USA-states",
    scope="usa",
    labels={"count": "NO OF EV's"},
    title="Number of EVs by State"
)
fig_1.update_layout(
    geo=dict(bgcolor="rgba(0,0,0,0)"),
    title_x=0.5
)

fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import warnings

make_year_data = df.groupby(['Model Year', 'Make'])['VIN (1-10)'].count().reset_index()
make_year_data.columns = ['Model Year', 'Make', 'Count']

fig = px.bar(
    make_year_data,
    x='Make',
    y='Count',
    color='Make',
    animation_frame='Model Year',
    animation_group='Make',
    range_y=[0, make_year_data['Count'].max() + 50],
    title='Electric Vehicle Makes Over Time',
    labels={'Count': 'Number of Vehicles', 'Make': 'EV Make'},
    text='Count'
)

fig.update_layout(
    title_font_size=20,
    xaxis_title_font_size=14,
    yaxis_title_font_size=14,
    legend_title_text='Electric Vehicle Make',
    margin=dict(l=40, r=40, t=40, b=40)
)

fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Car_per_year = df.groupby(['Make', 'Model Year']).size().reset_index(name='number_of_Vehicles')
print(Car_per_year)
# Out:
#       Make  Model Year  number_of_Vehicles
# 0     AUDI        2016                  19
# 1     AUDI        2017                  29
# 2     AUDI        2018                  25
# 3     AUDI        2019                  48
# 4     AUDI        2020                  21
# ..     ...         ...                 ...
# 182  VOLVO        2018                  36
# 183  VOLVO        2019                  21
# 184  VOLVO        2020                  18
# 185  VOLVO        2021                  71
# 186  VOLVO        2022                  94
#
# [187 rows x 3 columns]

# %%
fig = px.bar(
    Car_per_year,
    y='Make',
    x='number_of_Vehicles',
    color='Make',
    animation_frame='Model Year',
    orientation='h',
    title='EV Makes and their Count Over the Years',
    labels={'number_of_Vehicles': 'Number of EV Vehicles'},
    range_x=[0, 3000]
)

fig.update_traces(
    texttemplate='%{x}',
    textposition='outside',
    textfont_size=16
)

fig.update_layout(
    xaxis=dict(showgrid=True, gridcolor='LightGray'),
    yaxis_title='EV Makes',
    xaxis_title='Number of EV Vehicles',
    showlegend=False,
    title_x=0.5,
    title_font=dict(size=20),
    margin=dict(l=50, r=50, t=50, b=50),
    width=800,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
